# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-data/train/ad/ad_train_70.jpg
# /kaggle/input/train-data/train/ad/ad_train_55.jpg
# /kaggle/input/train-data/train/ad/ad_train_68.jpg
# /kaggle/input/train-data/train/ad/ad_train_41.jpg
# /kaggle/input/train-data/train/ad/ad_train_29.jpg
# /kaggle/input/train-data/train/ad/ad_train_50.jpg
# /kaggle/input/train-data/train/ad/ad_train_5.jpg
# /kaggle/input/train-data/train/ad/ad_train_60.jpg
# /kaggle/input/train-data/train/ad/ad_train_2.jpg
# /kaggle/input/train-data/train/ad/ad_train_72.jpg
# /kaggle/input/train-data/train/ad/ad_train_62.jpg
# /kaggle/input/train-data/train/ad/ad_train_14.jpg
# /kaggle/input/train-data/train/ad/ad_train_49.jpg
# /kaggle/input/train-data/train/ad/ad_train_4.jpg
# /kaggle/input/train-data/train/ad/ad_train_9.jpg
# /kaggle/input/train-data/train/ad/ad_train_71.jpg
# /kaggle/input/train-data/train/ad/ad_train_16.jpg
# /kaggle/input/train-data/train/ad/ad_train_44.jpg
# /kaggle/input/train-data/train/ad/ad_train_17.jpg
# /kaggle/input/train-data/train/ad/ad_train_63.jpg
# /kaggle/input/train-data/train/ad/ad_train_66.jpg
# /kaggle/input/train-data/train/ad/ad_train_48.jpg
# /kaggle/input/train-data/train/ad/ad_train_39.jpg
# /kaggle/input/train-data/train/ad/ad_train_23.jpg
# /kaggle/input/train-data/train/ad/ad_train_27.jpg
# /kaggle/input/train-data/train/ad/ad_train_77.jpg
# /kaggle/input/train-data/train/ad/ad_train_31.jpg
# /kaggle/input/train-data/train/ad/ad_train_19.jpg
# /kaggle/input/train-data/train/ad/ad_train_21.jpg
# /kaggle/input/train-data/train/ad/ad_train_10.jpg
# /kaggle/input/train-data/train/ad/ad_train_45.jpg
# /kaggle/input/train-data/train/ad/ad_train_51.jpg
# /kaggle/input/train-data/train/ad/ad_train_76.jpg
# /kaggle/input/train-data/train/ad/ad_train_43.jpg
# /kaggle/input/train-data/train/ad/ad_train_59.jpg
# /kaggle/input/train-data/train/ad/ad_train_57.jpg
# /kaggle/input/train-data/train/ad/ad_train_13.jpg
# /kaggle/input/train-data/train/ad/ad_train_74.jpg
# /kaggle/input/train-data/train/ad/ad_train_73.jpg
# /kaggle/input/train-data/train/ad/ad_train_1.jpg
# /kaggle/input/train-data/train/ad/ad_train_80.jpg
# /kaggle/input/train-data/train/ad/ad_train_8.jpg
# /kaggle/input/train-data/train/ad/ad_train_32.jpg
# /kaggle/input/train-data/train/ad/ad_train_7.jpg
# /kaggle/input/train-data/train/ad/ad_train_65.jpg
# /kaggle/input/train-data/train/ad/ad_train_25.jpg
# /kaggle/input/train-data/train/ad/ad_train_54.jpg
# /kaggle/input/train-data/train/ad/ad_train_36.jpg
# /kaggle/input/train-data/train/ad/ad_train_35.jpg
# /kaggle/input/train-data/train/ad/ad_train_78.jpg
# /kaggle/input/train-data/train/ad/ad_train_69.jpg
# /kaggle/input/train-data/train/ad/ad_train_67.jpg
# /kaggle/input/train-data/train/ad/ad_train_22.jpg
# /kaggle/input/train-data/train/ad/ad_train_37.jpg
# /kaggle/input/train-data/train/ad/ad_train_30.jpg
# /kaggle/input/train-data/train/ad/ad_train_28.jpg
# /kaggle/input/train-data/train/ad/ad_train_12.jpg
# /kaggle/input/train-data/train/ad/ad_train_47.jpg
# /kaggle/input/train-data/train/ad/ad_train_26.jpg
# /kaggle/input/train-data/train/ad/ad_train_24.jpg
# /kaggle/input/train-data/train/ad/ad_train_11.jpg
# /kaggle/input/train-data/train/ad/ad_train_61.jpg
# /kaggle/input/train-data/train/ad/ad_train_18.jpg
# /kaggle/input/train-data/train/ad/ad_train_34.jpg
# /kaggle/input/train-data/train/ad/ad_train_42.jpg
# /kaggle/input/train-data/train/ad/ad_train_58.jpg
# /kaggle/input/train-data/train/ad/ad_train_79.jpg
# /kaggle/input/train-data/train/ad/ad_train_64.jpg
# /kaggle/input/train-data/train/ad/ad_train_20.jpg
# /kaggle/input/train-data/train/ad/ad_train_40.jpg
# /kaggle/input/train-data/train/ad/ad_train_3.jpg
# /kaggle/input/train-data/train/ad/ad_train_56.jpg
# /kaggle/input/train-data/train/ad/ad_train_75.jpg
# /kaggle/input/train-data/train/ad/ad_train_38.jpg
# /kaggle/input/train-data/train/ad/ad_train_6.jpg
# /kaggle/input/train-data/train/ad/ad_train_46.jpg
# /kaggle/input/train-data/train/ad/ad_train_53.jpg
# /kaggle/input/train-data/train/ad/ad_train_15.jpg
# /kaggle/input/train-data/train/ad/ad_train_52.jpg
# /kaggle/input/train-data/train/ad/ad_train_33.jpg
# /kaggle/input/train-data/train/normal/normal_train_13.jpg
# /kaggle/input/train-data/train/normal/normal_train_26.jpg
# /kaggle/input/train-data/train/normal/normal_train_35.jpg
# /kaggle/input/train-data/train/normal/normal_train_47.jpg
# /kaggle/input/train-data/train/normal/normal_train_42.jpg
# /kaggle/input/train-data/train/normal/normal_train_76.jpg
# /kaggle/input/train-data/train/normal/normal_train_21.jpg
# /kaggle/input/train-data/train/normal/normal_train_17.jpg
# /kaggle/input/train-data/train/normal/normal_train_1.jpg
# /kaggle/input/train-data/train/normal/normal_train_48.jpg
# /kaggle/input/train-data/train/normal/normal_train_20.jpg
# /kaggle/input/train-data/train/normal/normal_train_6.jpg
# /kaggle/input/train-data/train/normal/normal_train_40.jpg
# /kaggle/input/train-data/train/normal/normal_train_28.jpg
# /kaggle/input/train-data/train/normal/normal_train_72.jpg
# /kaggle/input/train-data/train/normal/normal_train_44.jpg
# /kaggle/input/train-data/train/normal/normal_train_10.jpg
# /kaggle/input/train-data/train/normal/normal_train_71.jpg
# /kaggle/input/train-data/train/normal/normal_train_31.jpg
# /kaggle/input/train-data/train/normal/normal_train_29.jpg
# /kaggle/input/train-data/train/normal/normal_train_75.jpg
# /kaggle/input/train-data/train/normal/normal_train_2.jpg
# /kaggle/input/train-data/train/normal/normal_train_25.jpg
# /kaggle/input/train-data/train/normal/normal_train_14.jpg
# /kaggle/input/train-data/train/normal/normal_train_3.jpg
# /kaggle/input/train-data/train/normal/normal_train_18.jpg
# /kaggle/input/train-data/train/normal/normal_train_80.jpg
# /kaggle/input/train-data/train/normal/normal_train_62.jpg
# /kaggle/input/train-data/train/normal/normal_train_27.jpg
# /kaggle/input/train-data/train/normal/normal_train_52.jpg
# /kaggle/input/train-data/train/normal/normal_train_30.jpg
# /kaggle/input/train-data/train/normal/normal_train_8.jpg
# /kaggle/input/train-data/train/normal/normal_train_15.jpg
# /kaggle/input/train-data/train/normal/normal_train_65.jpg
# /kaggle/input/train-data/train/normal/normal_train_51.jpg
# /kaggle/input/train-data/train/normal/normal_train_58.jpg
# /kaggle/input/train-data/train/normal/normal_train_77.jpg
# /kaggle/input/train-data/train/normal/normal_train_9.jpg
# /kaggle/input/train-data/train/normal/normal_train_55.jpg
# /kaggle/input/train-data/train/normal/normal_train_43.jpg
# /kaggle/input/train-data/train/normal/normal_train_60.jpg
# /kaggle/input/train-data/train/normal/normal_train_41.jpg
# /kaggle/input/train-data/train/normal/normal_train_11.jpg
# /kaggle/input/train-data/train/normal/normal_train_36.jpg
# /kaggle/input/train-data/train/normal/normal_train_45.jpg
# /kaggle/input/train-data/train/normal/normal_train_34.jpg
# /kaggle/input/train-data/train/normal/normal_train_69.jpg
# /kaggle/input/train-data/train/normal/normal_train_19.jpg
# /kaggle/input/train-data/train/normal/normal_train_5.jpg
# /kaggle/input/train-data/train/normal/normal_train_78.jpg
# /kaggle/input/train-data/train/normal/normal_train_67.jpg
# /kaggle/input/train-data/train/normal/normal_train_22.jpg
# /kaggle/input/train-data/train/normal/normal_train_16.jpg
# /kaggle/input/train-data/train/normal/normal_train_56.jpg
# /kaggle/input/train-data/train/normal/normal_train_79.jpg
# /kaggle/input/train-data/train/normal/normal_train_12.jpg
# /kaggle/input/train-data/train/normal/normal_train_73.jpg
# /kaggle/input/train-data/train/normal/normal_train_33.jpg
# /kaggle/input/train-data/train/normal/normal_train_46.jpg
# /kaggle/input/train-data/train/normal/normal_train_49.jpg
# /kaggle/input/train-data/train/normal/normal_train_39.jpg
# /kaggle/input/train-data/train/normal/normal_train_74.jpg
# /kaggle/input/train-data/train/normal/normal_train_59.jpg
# /kaggle/input/train-data/train/normal/normal_train_7.jpg
# /kaggle/input/train-data/train/normal/normal_train_57.jpg
# /kaggle/input/train-data/train/normal/normal_train_70.jpg
# /kaggle/input/train-data/train/normal/normal_train_24.jpg
# /kaggle/input/train-data/train/normal/normal_train_53.jpg
# /kaggle/input/train-data/train/normal/normal_train_23.jpg
# /kaggle/input/train-data/train/normal/normal_train_37.jpg
# /kaggle/input/train-data/train/normal/normal_train_54.jpg
# /kaggle/input/train-data/train/normal/normal_train_68.jpg
# /kaggle/input/train-data/train/normal/normal_train_61.jpg
# /kaggle/input/train-data/train/normal/normal_train_64.jpg
# /kaggle/input/train-data/train/normal/normal_train_32.jpg
# /kaggle/input/train-data/train/normal/normal_train_38.jpg
# /kaggle/input/train-data/train/normal/normal_train_4.jpg
# /kaggle/input/train-data/train/normal/normal_train_66.jpg
# /kaggle/input/train-data/train/normal/normal_train_63.jpg
# /kaggle/input/train-data/train/normal/normal_train_50.jpg
# /kaggle/input/test-data/test/ad/ad_test_49.jpg
# /kaggle/input/test-data/test/ad/ad_test_47.jpg
# /kaggle/input/test-data/test/ad/ad_test_14.jpg
# /kaggle/input/test-data/test/ad/ad_test_27.jpg
# /kaggle/input/test-data/test/ad/ad_test_13.jpg
# /kaggle/input/test-data/test/ad/ad_test_20.jpg
# /kaggle/input/test-data/test/ad/ad_test_48.jpg
# /kaggle/input/test-data/test/ad/ad_test_7.jpg
# /kaggle/input/test-data/test/ad/ad_test_60.jpg
# /kaggle/input/test-data/test/ad/ad_test_44.jpg
# /kaggle/input/test-data/test/ad/ad_test_21.jpg
# /kaggle/input/test-data/test/ad/ad_test_45.jpg
# /kaggle/input/test-data/test/ad/ad_test_18.jpg
# /kaggle/input/test-data/test/ad/ad_test_33.jpg
# /kaggle/input/test-data/test/ad/ad_test_11.jpg
# /kaggle/input/test-data/test/ad/ad_test_2.jpg
# /kaggle/input/test-data/test/ad/ad_test_26.jpg
# /kaggle/input/test-data/test/ad/ad_test_9.jpg
# /kaggle/input/test-data/test/ad/ad_test_52.jpg
# /kaggle/input/test-data/test/ad/ad_test_40.jpg
# /kaggle/input/test-data/test/ad/ad_test_58.jpg
# /kaggle/input/test-data/test/ad/ad_test_59.jpg
# /kaggle/input/test-data/test/ad/ad_test_32.jpg
# /kaggle/input/test-data/test/ad/ad_test_55.jpg
# /kaggle/input/test-data/test/ad/ad_test_53.jpg
# /kaggle/input/test-data/test/ad/ad_test_6.jpg
# /kaggle/input/test-data/test/ad/ad_test_50.jpg
# /kaggle/input/test-data/test/ad/ad_test_29.jpg
# /kaggle/input/test-data/test/ad/ad_test_1.jpg
# /kaggle/input/test-data/test/ad/ad_test_37.jpg
# /kaggle/input/test-data/test/ad/ad_test_16.jpg
# /kaggle/input/test-data/test/ad/ad_test_19.jpg
# /kaggle/input/test-data/test/ad/ad_test_4.jpg
# /kaggle/input/test-data/test/ad/ad_test_24.jpg
# /kaggle/input/test-data/test/ad/ad_test_35.jpg
# /kaggle/input/test-data/test/ad/ad_test_42.jpg
# /kaggle/input/test-data/test/ad/ad_test_8.jpg
# /kaggle/input/test-data/test/ad/ad_test_34.jpg
# /kaggle/input/test-data/test/ad/ad_test_5.jpg
# /kaggle/input/test-data/test/ad/ad_test_38.jpg
# /kaggle/input/test-data/test/ad/ad_test_31.jpg
# /kaggle/input/test-data/test/ad/ad_test_36.jpg
# /kaggle/input/test-data/test/ad/ad_test_43.jpg
# /kaggle/input/test-data/test/ad/ad_test_10.jpg
# /kaggle/input/test-data/test/ad/ad_test_54.jpg
# /kaggle/input/test-data/test/ad/ad_test_15.jpg
# /kaggle/input/test-data/test/ad/ad_test_30.jpg
# /kaggle/input/test-data/test/ad/ad_test_3.jpg
# /kaggle/input/test-data/test/ad/ad_test_23.jpg
# /kaggle/input/test-data/test/ad/ad_test_25.jpg
# /kaggle/input/test-data/test/ad/ad_test_28.jpg
# /kaggle/input/test-data/test/ad/ad_test_12.jpg
# /kaggle/input/test-data/test/ad/ad_test_56.jpg
# /kaggle/input/test-data/test/ad/ad_test_51.jpg
# /kaggle/input/test-data/test/ad/ad_test_17.jpg
# /kaggle/input/test-data/test/ad/ad_test_57.jpg
# /kaggle/input/test-data/test/ad/ad_test_41.jpg
# /kaggle/input/test-data/test/ad/ad_test_39.jpg
# /kaggle/input/test-data/test/ad/ad_test_22.jpg
# /kaggle/input/test-data/test/ad/ad_test_46.jpg
# /kaggle/input/test-data/test/normal/normal_test_36.jpg
# /kaggle/input/test-data/test/normal/normal_test_22.jpg
# /kaggle/input/test-data/test/normal/normal_test_58.jpg
# /kaggle/input/test-data/test/normal/normal_test_18.jpg
# /kaggle/input/test-data/test/normal/normal_test_20.jpg
# /kaggle/input/test-data/test/normal/normal_test_26.jpg
# /kaggle/input/test-data/test/normal/normal_test_9.jpg
# /kaggle/input/test-data/test/normal/normal_test_11.jpg
# /kaggle/input/test-data/test/normal/normal_test_59.jpg
# /kaggle/input/test-data/test/normal/normal_test_40.jpg
# /kaggle/input/test-data/test/normal/normal_test_54.jpg
# /kaggle/input/test-data/test/normal/normal_test_49.jpg
# /kaggle/input/test-data/test/normal/normal_test_21.jpg
# /kaggle/input/test-data/test/normal/normal_test_33.jpg
# /kaggle/input/test-data/test/normal/normal_test_45.jpg
# /kaggle/input/test-data/test/normal/normal_test_60.jpg
# /kaggle/input/test-data/test/normal/normal_test_47.jpg
# /kaggle/input/test-data/test/normal/normal_test_3.jpg
# /kaggle/input/test-data/test/normal/normal_test_8.jpg
# /kaggle/input/test-data/test/normal/normal_test_16.jpg
# /kaggle/input/test-data/test/normal/normal_test_15.jpg
# /kaggle/input/test-data/test/normal/normal_test_4.jpg
# /kaggle/input/test-data/test/normal/normal_test_38.jpg
# /kaggle/input/test-data/test/normal/normal_test_19.jpg
# /kaggle/input/test-data/test/normal/normal_test_35.jpg
# /kaggle/input/test-data/test/normal/normal_test_29.jpg
# /kaggle/input/test-data/test/normal/normal_test_2.jpg
# /kaggle/input/test-data/test/normal/normal_test_50.jpg
# /kaggle/input/test-data/test/normal/normal_test_48.jpg
# /kaggle/input/test-data/test/normal/normal_test_51.jpg
# /kaggle/input/test-data/test/normal/normal_test_46.jpg
# /kaggle/input/test-data/test/normal/normal_test_27.jpg
# /kaggle/input/test-data/test/normal/normal_test_10.jpg
# /kaggle/input/test-data/test/normal/normal_test_14.jpg
# /kaggle/input/test-data/test/normal/normal_test_17.jpg
# /kaggle/input/test-data/test/normal/normal_test_12.jpg
# /kaggle/input/test-data/test/normal/normal_test_5.jpg
# /kaggle/input/test-data/test/normal/normal_test_55.jpg
# /kaggle/input/test-data/test/normal/normal_test_42.jpg
# /kaggle/input/test-data/test/normal/normal_test_56.jpg
# /kaggle/input/test-data/test/normal/normal_test_53.jpg
# /kaggle/input/test-data/test/normal/normal_test_43.jpg
# /kaggle/input/test-data/test/normal/normal_test_7.jpg
# /kaggle/input/test-data/test/normal/normal_test_31.jpg
# /kaggle/input/test-data/test/normal/normal_test_30.jpg
# /kaggle/input/test-data/test/normal/normal_test_24.jpg
# /kaggle/input/test-data/test/normal/normal_test_1.jpg
# /kaggle/input/test-data/test/normal/normal_test_37.jpg
# /kaggle/input/test-data/test/normal/normal_test_23.jpg
# /kaggle/input/test-data/test/normal/normal_test_41.jpg
# /kaggle/input/test-data/test/normal/normal_test_34.jpg
# /kaggle/input/test-data/test/normal/normal_test_13.jpg
# /kaggle/input/test-data/test/normal/normal_test_39.jpg
# /kaggle/input/test-data/test/normal/normal_test_32.jpg
# /kaggle/input/test-data/test/normal/normal_test_57.jpg
# /kaggle/input/test-data/test/normal/normal_test_25.jpg
# /kaggle/input/test-data/test/normal/normal_test_52.jpg
# /kaggle/input/test-data/test/normal/normal_test_44.jpg
# /kaggle/input/test-data/test/normal/normal_test_28.jpg
# /kaggle/input/test-data/test/normal/normal_test_6.jpg

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, initializers, regularizers, metrics

# %%
np.random.seed(3)
tf.random.set_seed(3)

# %%
train_datagen = ImageDataGenerator(rescale= '1./255',
                                   horizontal_flip=True,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   fill_mode='nearest')

# %%
"""
캐글에서는 캐글 내 경로를 이용해야한다.
책에서는 주피터를 이용해서 경로가 ./train 으로 나와있는데
나는 데이터 폴더를 업로드 해서 그 경로를 이용했더니 문제가 해결됐다. 
"""
train_generator = train_datagen.flow_from_directory('../input/train-data/train',  
                                                    target_size=(150,150),
                                                    batch_size=5,
                                                    class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
test_generator = test_datagen.flow_from_directory('../input/test-data/test',
                                                  target_size=(150,150),
                                                  batch_size=5,
                                                  class_mode='binary')
# Out:
# Found 120 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(32, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('sigmoid'))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer=optimizers.Adam(learning_rate = 0.0002), metrics = ['accuracy'])

# %%
history = model.fit_generator(
       train_generator,
       steps_per_epoch=100,
       epochs=20,
       validation_data=test_generator,
       validation_steps=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-91c542e1cd55> in <module>
# ----> 1 train_generator.astype(np.float32)
#       2 history = model.fit_generator(
#       3        train_generator,
#       4        steps_per_epoch=100,
#       5        epochs=20,
#
# AttributeError: 'DirectoryIterator' object has no attribute 'astype'
